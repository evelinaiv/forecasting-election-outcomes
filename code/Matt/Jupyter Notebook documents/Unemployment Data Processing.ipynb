# %%
import sqlite3 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
Unemployment = pd.read_csv(r'C:\Users\Matth\Downloads\Unemployment.csv')

# %%
#Setting Country name as the index
Unemployment.set_index(Unemployment.columns[0], inplace=True)

# %%
#Removing junk rows
Unemployment.drop(Unemployment.columns[0:3], axis=1, inplace=True)

# %%
#Moving the years to index
Unemployment = Unemployment.transpose()

# %%
#For Unemployment there is no data until 1990 so this is removed
Unemployment.drop(Unemployment.index[0:31], axis=0, inplace=True)

# %%
Unemployment.head()
# Out:
# Country Name  Aruba  Africa Eastern and Southern  Afghanistan  \
# 1991            NaN                     7.801597        7.946
# 1992            NaN                     7.896982        7.940
# 1993            NaN                     7.898076        7.961
# 1994            NaN                     7.768859        7.980
# 1995            NaN                     7.533566        7.967
#
# Country Name  Africa Western and Central  Angola  Albania  Andorra  \
# 1991                            4.158535  16.468   10.304      NaN
# 1992                            4.277885  16.621   30.007      NaN
# 1993                            4.376871  17.074   25.251      NaN
# 1994                            4.399825  17.105   20.835      NaN
# 1995                            4.390342  16.711   14.607      NaN
#
# Country Name  Arab World  United Arab Emirates  Argentina  ...  \
# 1991           11.799435                 1.645       5.44  ...
# ...

# %%
#Removing countries with little to no data

non_null_count = Unemployment.count()

non_null_perc = (non_null_count/len(Unemployment)) *100

columns_to_drop = non_null_perc[non_null_perc <= 10].index

Unemployment = Unemployment.drop(columns=columns_to_drop)

Unemployment.head()
# Out:
# Country Name  Africa Eastern and Southern  Afghanistan  \
# 1991                             7.801597        7.946
# 1992                             7.896982        7.940
# 1993                             7.898076        7.961
# 1994                             7.768859        7.980
# 1995                             7.533566        7.967
#
# Country Name  Africa Western and Central  Angola  Albania  Arab World  \
# 1991                            4.158535  16.468   10.304   11.799435
# 1992                            4.277885  16.621   30.007   12.035881
# 1993                            4.376871  17.074   25.251   12.812291
# 1994                            4.399825  17.105   20.835   12.924423
# 1995                            4.390342  16.711   14.607   13.416831
#
# Country Name  United Arab Emirates  Argentina  Armenia  Australia  ...  \
# 1991                         1.645       5.44      1.6      9.586  ...
# ...

# %%
#Creating a dataset which contains percentage changes in inflation in each year
Unemployment_perc_change = Unemployment.pct_change() * 100
Unemployment_perc_change.head()
# Out:
# Country Name  Africa Eastern and Southern  Afghanistan  \
# 1991                                  NaN          NaN
# 1992                             1.222635    -0.075510
# 1993                             0.013853     0.264484
# 1994                            -1.636056     0.238663
# 1995                            -3.028671    -0.162907
#
# Country Name  Africa Western and Central    Angola     Albania  Arab World  \
# 1991                                 NaN       NaN         NaN         NaN
# 1992                            2.870009  0.929075  191.217003    2.003876
# 1993                            2.313898  2.725468  -15.849635    6.450797
# 1994                            0.524443  0.181563  -17.488416    0.875195
# 1995                           -0.215545 -2.303420  -29.892009    3.809897
#
# Country Name  United Arab Emirates  Argentina     Armenia  Australia  ...  \
# 1991                           NaN        NaN         NaN        NaN  ...
# ...

# %%
#Now we have two nice and usable dataframes

# %%
Unemployment.to_csv('Unemployment.csv', index=True)
Unemployment_perc_change.to_csv('Unemployment_perc_change.csv', index=True)
