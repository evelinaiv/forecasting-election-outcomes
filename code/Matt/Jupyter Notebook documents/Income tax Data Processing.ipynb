# %%
import sqlite3 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
#Because the OECD data website sucks, I could only download a certain amount of data at once (6000 cells), so in order to get all the countries they 
#have data on I needed to download 3 different excel sheets (used Excel sheets as they were a lot more usable than the csv formats).

IncomeTax1 = pd.read_excel(r'C:\Users\Matth\Downloads\Income tax 1.xlsx', sheet_name="Table")
IncomeTax2 = pd.read_excel(r'C:\Users\Matth\Downloads\Income tax 2.xlsx', sheet_name="Table")
IncomeTax3 = pd.read_excel(r'C:\Users\Matth\Downloads\Income tax 3.xlsx', sheet_name="Table")

#These are all the formated the same so I can repeat operations on them in a set

IncomeTax = [IncomeTax1, IncomeTax2, IncomeTax3]

# %%
IncomeTax1.head()
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
#   Table I.1. Central government personal income tax rates and thresholds  \
# 0                                                NaN
# 1                                               Year
# 2                                            Country
# 3  Central government personal income tax rates a...
# 4                                              Italy
#
#   Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1       Year      2000.0      2001.0      2002.0      2003.0      2004.0
# 2        NaN         NaN         NaN         NaN         NaN         NaN
# 3        NaN         NaN         NaN         NaN         NaN         NaN
# 4        NaN         NaN         NaN         NaN      7500.0      7500.0
#
#    Unnamed: 8  Unnamed: 9  ...  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0         NaN         NaN  ...          NaN          NaN          NaN
# 1      2005.0      2006.0  ...       2013.0       2014.0       2015.0
# 2         NaN         NaN  ...          NaN          NaN          NaN
# 3         NaN         NaN  ...          NaN          NaN          NaN
# 4      7500.0      7500.0  ...          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21  Unnamed: 22  Unnamed: 23  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1       2016.0       2017.0       2018.0       2019.0       2020.0
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 24  Unnamed: 25
# 0          NaN          NaN
# 1       2021.0       2022.0
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 26 columns]

# %%
#Removing junk rows and columns, transposing and setting correct index and columns

for df in IncomeTax:
    df.drop(df.columns[0], axis=1, inplace=True)
    df.drop(df.index[0], axis=0, inplace=True)

# %%
for df in IncomeTax:
        df.set_index(df.columns[0], inplace=True)

# %%
for df in IncomeTax:
    df.columns = df.iloc[0]  # Set column names to first row
    df.drop(df.index[0], inplace=True)  # Remove the first row

# %%
#Dropping more junk rows
for df in IncomeTax:
    df.drop(df.columns[0], axis=1, inplace=True)
    df.drop(df.index[0], axis=0, inplace=True)

# %%
#I had weirdness with transposing here... ignore this
IncomeTax1 = IncomeTax1.transpose()
IncomeTax2 = IncomeTax2.transpose()
IncomeTax3 = IncomeTax3.transpose()

IncomeTax = [IncomeTax1, IncomeTax2, IncomeTax3]

# %%
#Standardising the Year (index) names to match with other dataframes as they translated weirdly
for df in IncomeTax:
    df.index = df.index.astype(int)

IncomeTax1.head()
# Out:
# Table I.1. Central government personal income tax rates and thresholds  Central government personal income tax rates and thresholds: Personal allowance  \
# Year
# 2000                                                                                                                  NaN
# 2001                                                                                                                  NaN
# 2002                                                                                                                  NaN
# 2003                                                                                                                  NaN
# 2004                                                                                                                  NaN
#
# Table I.1. Central government personal income tax rates and thresholds   Italy  \
# Year
# 2000                                                                       NaN
# 2001                                                                       NaN
# 2002                                                                       NaN
# 2003                                                                    7500.0
# 2004                                                                    7500.0
#
# Table I.1. Central government personal income tax rates and thresholds  Japan  \
# Year
# 2000                                                                    380.0
# 2001                                                                    380.0
# 2002                                                                    380.0
# 2003                                                                    380.0
# 2004                                                                    380.0
#
# Table I.1. Central government personal income tax rates and thresholds     Korea  \
# Year
# 2000                                                                    600000.0
# 2001                                                                    600000.0
# 2002                                                                    600000.0
# 2003                                                                    600000.0
# 2004                                                                    600000.0
#
# Table I.1. Central government personal income tax rates and thresholds   Mexico  \
# Year
# 2000                                                                    1580.00
# 2001                                                                    1690.65
# 2002                                                                    1788.30
# 2003                                                                    1865.85
# 2004                                                                    1948.05
#
# Table I.1. Central government personal income tax rates and thresholds  Netherlands  \
# Year
# 2000                                                                         3868.0
# 2001                                                                            NaN
# 2002                                                                            NaN
# 2003                                                                            NaN
# 2004                                                                            NaN
#
# Table I.1. Central government personal income tax rates and thresholds   Norway  \
# Year
# 2000                                                                    64300.0
# 2001                                                                    69100.0
# 2002                                                                    73100.0
# 2003                                                                    77300.0
# 2004                                                                    80400.0
#
# Table I.1. Central government personal income tax rates and thresholds   Poland  \
# Year
# 2000                                                                     982.08
# 2001                                                                    1110.72
# 2002                                                                    1155.12
# 2003                                                                    1199.52
# 2004                                                                    1227.00
#
# Table I.1. Central government personal income tax rates and thresholds  Türkiye  \
# Year
# 2000                                                                      225.0
# 2001                                                                      262.8
# 2002                                                                      360.0
# 2003                                                                      540.0
# 2004                                                                        NaN
#
# Table I.1. Central government personal income tax rates and thresholds  United Kingdom  \
# Year
# 2000                                                                            4385.0
# 2001                                                                            4535.0
# 2002                                                                            4615.0
# 2003                                                                            4615.0
# 2004                                                                            4745.0
#
# Table I.1. Central government personal income tax rates and thresholds  ...  \
# Year                                                                    ...
# 2000                                                                    ...
# 2001                                                                    ...
# 2002                                                                    ...
# 2003                                                                    ...
# 2004                                                                    ...
#
# Table I.1. Central government personal income tax rates and thresholds  Central government personal income tax rates and thresholds: 10 Threshold  \
# Year
# 2000                                                                                                                  NaN
# 2001                                                                                                                  NaN
# 2002                                                                                                                  NaN
# 2003                                                                                                                  NaN
# 2004                                                                                                                  NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Austria  \
# Year
# 2000                                                                    36336.0
# 2001                                                                    50871.0
# 2002                                                                        NaN
# 2003                                                                        NaN
# 2004                                                                        NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Mexico  \
# Year
# 2000                                                                       NaN
# 2001                                                                       NaN
# 2002                                                                       NaN
# 2003                                                                       NaN
# 2004                                                                       NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Central government personal income tax rates and thresholds: 11 Marginal rate  \
# Year
# 2000                                                                                                                  NaN
# 2001                                                                                                                  NaN
# 2002                                                                                                                  NaN
# 2003                                                                                                                  NaN
# 2004                                                                                                                  NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Austria  \
# Year
# 2000                                                                       42.0
# 2001                                                                       50.0
# 2002                                                                        NaN
# 2003                                                                        NaN
# 2004                                                                        NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Mexico  \
# Year
# 2000                                                                       NaN
# 2001                                                                       NaN
# 2002                                                                       NaN
# 2003                                                                       NaN
# 2004                                                                       NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Central government personal income tax rates and thresholds: 11 Threshold  \
# Year
# 2000                                                                                                                  NaN
# 2001                                                                                                                  NaN
# 2002                                                                                                                  NaN
# 2003                                                                                                                  NaN
# 2004                                                                                                                  NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Austria  \
# Year
# 2000                                                                    50871.0
# 2001                                                                        NaN
# 2002                                                                        NaN
# 2003                                                                        NaN
# 2004                                                                        NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Central government personal income tax rates and thresholds: 12 Marginal rate  \
# Year
# 2000                                                                                                                  NaN
# 2001                                                                                                                  NaN
# 2002                                                                                                                  NaN
# 2003                                                                                                                  NaN
# 2004                                                                                                                  NaN
#
# Table I.1. Central government personal income tax rates and thresholds  Austria
# Year
# 2000                                                                       50.0
# 2001                                                                        NaN
# 2002                                                                        NaN
# 2003                                                                        NaN
# 2004                                                                        NaN
#
# [5 rows x 253 columns]

# %%
#Now I have my dataset and need to organise it until a usable way.
#I believe we could split it up into different datasets. 
#Currencies need to be normalised, which can be done using my currency dataframe.

# %%
IncomeTax1.to_csv('IncomeTax1.csv', index=True)
IncomeTax2.to_csv('IncomeTax2.csv', index=True)
IncomeTax3.to_csv('IncomeTax3.csv', index=True)
