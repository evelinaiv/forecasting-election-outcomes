# %%
import sqlite3 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
CurrencyPerDollar = pd.read_csv(r'C:\Users\Matth\Downloads\USD Exchange Rates.csv')

# %%
#Setting Country name as the index
CurrencyPerDollar.set_index(CurrencyPerDollar.columns[0], inplace=True)

# %%
#Removing junk rows
CurrencyPerDollar.drop(CurrencyPerDollar.columns[0:3], axis=1, inplace=True)

# %%
#Moving the years to index
CurrencyPerDollar = CurrencyPerDollar.transpose()

# %%
CurrencyPerDollar.head()
# Out:
# Country Name  Aruba  Africa Eastern and Southern  Afghanistan  \
# 1960            NaN                          NaN    17.196561
# 1961            NaN                          NaN    17.196561
# 1962            NaN                          NaN    17.196561
# 1963            NaN                          NaN    35.109645
# 1964            NaN                          NaN    38.692262
#
# Country Name  Africa Western and Central        Angola  Albania  Andorra  \
# 1960                                 NaN  2.870000e-08      NaN      NaN
# 1961                                 NaN  2.870000e-08      NaN      NaN
# 1962                                 NaN  2.870000e-08      NaN      NaN
# 1963                                 NaN  2.880000e-08      NaN      NaN
# 1964                                 NaN  2.880000e-08      NaN      NaN
#
# Country Name  Arab World  United Arab Emirates     Argentina  ...  \
# 1960                 NaN                   NaN           NaN  ...
# ...

# %%
CurrencyPerDollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64 entries, 1960 to 2023
# Columns: 266 entries, Aruba to Zimbabwe
# dtypes: float64(266)
# memory usage: 133.5+ KB

# %%
#Removing countries with little to no data

non_null_count = CurrencyPerDollar.count()

non_null_perc = (non_null_count/len(CurrencyPerDollar)) *100

columns_to_drop = non_null_perc[non_null_perc <= 10].index

CurrencyPerDollar = CurrencyPerDollar.drop(columns=columns_to_drop)

CurrencyPerDollar.head()
# Out:
# Country Name  Aruba  Afghanistan        Angola  Albania  United Arab Emirates  \
# 1960            NaN    17.196561  2.870000e-08      NaN                   NaN
# 1961            NaN    17.196561  2.870000e-08      NaN                   NaN
# 1962            NaN    17.196561  2.870000e-08      NaN                   NaN
# 1963            NaN    35.109645  2.880000e-08      NaN                   NaN
# 1964            NaN    38.692262  2.880000e-08      NaN                   NaN
#
# Country Name     Argentina  Armenia  Antigua and Barbuda  Australia  Austria  \
# 1960                   NaN      NaN              1.71429   0.892857     26.0
# 1961                   NaN      NaN              1.71429   0.892857     26.0
# 1962                   NaN      NaN              1.71429   0.892857     26.0
# 1963          1.390000e-11      NaN              1.71429   0.892857     26.0
# 1964          1.400000e-11      NaN              1.71429   0.892857     26.0
#
# ...

# %%
#Now we a nice and usable dataframe

# %%
CurrencyPerDollar.to_csv('Currency Per Dollar.csv', index=True)
