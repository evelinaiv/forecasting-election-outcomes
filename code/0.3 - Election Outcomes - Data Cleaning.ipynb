# %% [markdown]
# https://docs.google.com/document/d/172QhFesRsvPLJEQvqQCWtUB5BjUT4UbkL4ZvTHsMuvg/edit?tab=t.0

# %% [markdown]
# # The election results dataset
#
# https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/2VZ5ZC

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re


import sqlite3 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Pulling the data from the db into a pandas df

# %%
# Define the database path
db_path = "/work/Connor Folder/parlgov-stable.db"

# Connect to the SQLite database
conn = sqlite3.connect(db_path)

# Query the entire table 'view_election'
query = "SELECT * FROM view_election;"
# Fetch the results into a pandas DataFrame
election_df = pd.read_sql(query, conn)

# Close the connection
conn.close()

# Display the resulting DataFrame
election_df.head()
# Out:
#   country_name_short country_name election_type election_date  vote_share  \
# 0                AUS    Australia    parliament    1901-03-30        44.4
# 1                AUS    Australia    parliament    1901-03-30        34.2
# 2                AUS    Australia    parliament    1901-03-30        19.4
# 3                AUS    Australia    parliament    1901-03-30         1.4
# 4                AUS    Australia    parliament    1901-03-30         0.6
#
#    seats  seats_total party_name_short              party_name  \
# 0   32.0           75               PP     Protectionist Party
# 1   26.0           75              FTP        Free Trade Party
# 2   15.0           75              ALP  Australian Labor Party
# 3    1.0           75             none    no party affiliation
# 4    1.0           75         one-seat                one seat
#
#        party_name_english  left_right  country_id  election_id  \
# 0     Protectionist Party      7.4000          33          731
# 1        Free Trade Party      6.0000          33          731
# 2  Australian Labor Party      3.8833          33          731
# 3    no party affiliation         NaN          33          731
# 4                one seat         NaN          33          731
#
#    previous_parliament_election_id  previous_cabinet_id  party_id
# 0                              NaN                  NaN      1898
# 1                              NaN                  NaN      1938
# 2                              NaN                  NaN      1253
# 3                              NaN                  NaN      1396
# 4                              NaN                  NaN      2299

# %% [markdown]
# ## Exploring the countries in the table

# %%
# Extract a list of distinct country_name values from the election_df
distinct_countries = election_df['country_name'].drop_duplicates().tolist()
print(f" The number of countries in the DF: {len(distinct_countries)}")
print(f"\nThe list of countries:\n{distinct_countries}")
# Out:
#  The number of countries in the DF: 37
#
# The list of countries:
# ['Australia', 'Austria', 'Belgium', 'Bulgaria', 'Canada', 'Switzerland', 'Cyprus', 'Czech Republic', 'Germany', 'Denmark', 'Spain', 'Estonia', 'Finland', 'France', 'United Kingdom', 'Greece', 'Croatia', 'Hungary', 'Ireland', 'Iceland', 'Israel', 'Italy', 'Japan', 'Lithuania', 'Luxembourg', 'Latvia', 'Malta', 'Netherlands', 'Norway', 'New Zealand', 'Poland', 'Portugal', 'Romania', 'Slovakia', 'Slovenia', 'Sweden', 'Turkey']

# %% [markdown]
# # Cleaning the DF with Functions

# %% [markdown]
# <hr>

# %% [markdown]
# ### Filtering to only desired countries

# %%
#Create filter function
def filterCountries(df, filter, colName):
    return df[df[colName].isin(filter)]

# %% [markdown]
# ### Removing NaN years (no data collected in these years)

# %% [markdown]
# This leaves a nice year range, 1946-2019 (73 years) down from 122 years

# %%
# Remove columns (years) where there are NaNs in the data
def removeNullYears(df):
    df = df.dropna(axis=1, how='any')
    return df

# %%
# Alternative to removing null years, set them to 'False'
def falseNullYears(df):
    df = df.fillna(False)
    return df

# %% [markdown]
# ### Tracking the majority government each year

# %%
# def majority_government_each_year(df):
#     # Filter for only parliament elections
#     df = df[df['election_type'] == 'parliament']

#     # Sort by country and election date
#     df = df.sort_values(by=['country_name', 'election_date'])
    
#     results = {}

#     # Process each country separately
#     for country, group in df.groupby('country_name'):
#         group['election_date'] = pd.to_datetime(group['election_date'])  # Ensure dates are in datetime format
#         group = group.sort_values('election_date')

#         # Determine the majority party for each election
#         group['majority_party'] = group.groupby('election_id')['vote_share'].transform(max) == group['vote_share']
#         majority_parties = group[group['majority_party']].drop_duplicates('election_id')

#         # Map each year to the majority party
#         years = pd.date_range(start=group['election_date'].min(), end=group['election_date'].max(), freq='Y').year
#         party_map = {}
#         for i, row in majority_parties.iterrows():
#             start_year = row['election_date'].year if isinstance(row['election_date'], pd.Timestamp) else pd.to_datetime(row['election_date']).year
#             next_election = majority_parties['election_date'][majority_parties['election_date'] > row['election_date']].min()
#             end_year = next_election.year if pd.notna(next_election) else group['election_date'].max().year
#             for year in range(start_year, end_year + 1):
#                 party_map[year] = row['party_name_english']

#         # Adjust results for this country
#         results[country] = party_map

#     # Convert the results to a DataFrame
#     result_df = pd.DataFrame(results).T
#     result_df.index.name = 'country'
#     return result_df

# %%
def majority_government_each_year(df):

    # Filter for only parliament elections
    df = df[df['election_type'] == 'parliament']
    
    # Ensure election_date is in datetime format
    df['election_date'] = pd.to_datetime(df['election_date'])
    
    # Sort by country and election date
    df = df.sort_values(by=['country_name', 'election_date'])
    
    results = {}
    
    for country, group in df.groupby('country_name'):
        # Determine the majority party for each election
        group['majority_party'] = group.groupby('election_id')['vote_share'].transform(max) == group['vote_share']
        majority_parties = group[group['majority_party']].drop_duplicates('election_id')
        
        # Map election years to majority party
        party_map = {row['election_date'].year: row['party_name_english'] for _, row in majority_parties.iterrows()}
        results[country] = party_map
    
    # Convert to DataFrame
    result_df = pd.DataFrame.from_dict(results, orient='index')
    result_df.index.name = 'country'
    
    result_df = result_df.sort_index(axis=1, ascending=True)

    return result_df

# %% [markdown]
# ### Tracking when a majority government is overthrown (as a bool)

# %%
# Function to detect government changes
def calculate_government_changes(df):
    def check_changes(series):
        previous = None
        result = []
        
        for value in series:
            if pd.isna(value):
                result.append(np.nan)  # Keep NaNs as NaNs
            else:
                result.append(previous != value if previous is not None else False)
                previous = value  # Update previous only if the value is not NaN
        
        return result

    return df.apply(check_changes)

# %% [markdown]
# <hr>

# %% [markdown]
# # Applying the funcs

# %% [markdown]
# Line 8: "removeNullYears" will return only years where all countries have data. This returns less data but can be trusted.

# %% [markdown]
# Line 9: "falseNullYears" will return all years 1900-2023. NaNs are replaced with "False". This returns far more data but shouldn't be trusted.

# %% [markdown]
# (TLDR: Only one of these should be used, I recommend removeNullYears)

# %%
majority_govs_df = election_df.copy()

# G7_countries = ['Japan', 'Germany', 'France', 'United Kingdom', 'Italy', 'Canada'] 
# majority_govs_df = filterCountries(majority_govs_df, G7_countries, 'country_name')

majority_govs_df = majority_government_each_year(majority_govs_df)

#majority_govs_df = removeNullYears(majority_govs_df)
# majority_govs_df = falseNullYears(majority_govs_df)

majority_govs_df.T.head(20)
# Out:
# country                       Australia           Denmark  \
# 1900                                NaN               NaN
# 1901                Protectionist Party     Liberal Party
# 1902                                NaN               NaN
# 1903                   Free Trade Party     Liberal Party
# 1904                                NaN               NaN
# 1905                                NaN               NaN
# 1906                   Free Trade Party     Liberal Party
# 1908                                NaN               NaN
# 1909                                NaN  Social Democrats
# 1910             Australian Labor Party     Liberal Party
# 1911                                NaN               NaN
# 1912                                NaN               NaN
# 1913         Commonwealth Liberal Party  Social Democrats
# 1914             Australian Labor Party               NaN
# 1915                                NaN               NaN
# 1917     Nationalist Party of Australia               NaN
# 1918                                NaN     Liberal Party
# 1919     Nationalist Party of Australia               NaN
# 1920                                NaN     Liberal Party
# 1921                                NaN               NaN
#
# country                   Norway               Belgium  \
# 1900     Liberal Party of Norway        Catholic Party
# 1901                         NaN                   NaN
# 1902                         NaN        Catholic Party
# 1903          Conservative Party                   NaN
# 1904                         NaN        Catholic Party
# 1905                         NaN                   NaN
# 1906     Liberal Party of Norway        Catholic Party
# 1908                         NaN        Catholic Party
# 1909          Conservative Party                   NaN
# 1910                         NaN        Catholic Party
# 1911                         NaN                   NaN
# 1912     Liberal Party of Norway        Catholic Party
# 1913                         NaN                   NaN
# 1914                         NaN        Catholic Party
# 1915     Liberal Party of Norway                   NaN
# 1917                         NaN                   NaN
# 1918      Norwegian Labour Party                   NaN
# 1919                         NaN  Belgian Labour Party
# 1920                         NaN                   NaN
# 1921          Conservative Party        Catholic Party
#
# country                      France                New Zealand  \
# 1900                            NaN                        NaN
# 1901                            NaN                        NaN
# 1902               Left Republican   New Zealand Liberal Party
# 1903                            NaN                        NaN
# 1904                            NaN                        NaN
# 1905                            NaN  New Zealand Liberal Party
# 1906                  Conservatives                        NaN
# 1908                            NaN  New Zealand Liberal Party
# 1909                            NaN                        NaN
# 1910     Republican Socialist Party                        NaN
# 1911                            NaN  New Zealand Liberal Party
# 1912                            NaN                        NaN
# 1913                            NaN                        NaN
# 1914               Republican Union               Reform Party
# 1915                            NaN                        NaN
# 1917                            NaN                        NaN
# 1918                            NaN                        NaN
# 1919                Socialist Party               Reform Party
# 1920                            NaN                        NaN
# 1921                            NaN                        NaN
#
# country            Sweden               Switzerland  \
# 1900                  NaN                       NaN
# 1901                  NaN                       NaN
# 1902                  NaN  Radical Democratic Party
# 1903                  NaN                       NaN
# 1904                  NaN                       NaN
# 1905                  NaN  Radical Democratic Party
# 1906                  NaN                       NaN
# 1908                  NaN  Radical Democratic Party
# 1909                  NaN                       NaN
# 1910                  NaN                       NaN
# 1911       People's Party  Radical Democratic Party
# 1912                  NaN                       NaN
# 1913                  NaN                       NaN
# 1914       Moderate Party  Radical Democratic Party
# 1915                  NaN                       NaN
# 1917     Social Democrats  Radical Democratic Party
# 1918                  NaN                       NaN
# 1919                  NaN  Radical Democratic Party
# 1920     Social Democrats                       NaN
# 1921     Social Democrats                       NaN
#
# country                                    Canada  \
# 1900                      Liberal Party of Canada
# 1901                                          NaN
# 1902                                          NaN
# 1903                                          NaN
# 1904                      Liberal Party of Canada
# 1905                                          NaN
# 1906                                          NaN
# 1908                      Liberal Party of Canada
# 1909                                          NaN
# 1910                                          NaN
# 1911     Progressive Conservative Party of Canada
# 1912                                          NaN
# 1913                                          NaN
# 1914                                          NaN
# 1915                                          NaN
# 1917     Progressive Conservative Party of Canada
# 1918                                          NaN
# 1919                                          NaN
# 1920                                          NaN
# 1921                      Liberal Party of Canada
#
# country                             Finland  ... Latvia Romania Slovakia  \
# 1900                                    NaN  ...    NaN     NaN      NaN
# 1901                                    NaN  ...    NaN     NaN      NaN
# 1902                                    NaN  ...    NaN     NaN      NaN
# 1903                                    NaN  ...    NaN     NaN      NaN
# 1904                                    NaN  ...    NaN     NaN      NaN
# 1905                                    NaN  ...    NaN     NaN      NaN
# 1906                                    NaN  ...    NaN     NaN      NaN
# 1908                                    NaN  ...    NaN     NaN      NaN
# 1909                                    NaN  ...    NaN     NaN      NaN
# 1910                                    NaN  ...    NaN     NaN      NaN
# 1911                                    NaN  ...    NaN     NaN      NaN
# 1912                                    NaN  ...    NaN     NaN      NaN
# 1913                                    NaN  ...    NaN     NaN      NaN
# 1914                                    NaN  ...    NaN     NaN      NaN
# 1915                                    NaN  ...    NaN     NaN      NaN
# 1917     Social Democratic Party of Finland  ...    NaN     NaN      NaN
# 1918                                    NaN  ...    NaN     NaN      NaN
# 1919     Social Democratic Party of Finland  ...    NaN     NaN      NaN
# 1920                                    NaN  ...    NaN     NaN      NaN
# 1921                                    NaN  ...    NaN     NaN      NaN
#
# country Slovenia Poland Cyprus Lithuania Bulgaria Croatia Estonia
# 1900         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1901         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1902         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1903         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1904         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1905         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1906         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1908         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1909         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1910         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1911         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1912         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1913         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1914         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1915         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1917         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1918         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1919         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1920         NaN    NaN    NaN       NaN      NaN     NaN     NaN
# 1921         NaN    NaN    NaN       NaN      NaN     NaN     NaN
#
# [20 rows x 37 columns]

# %%
df = majority_govs_df.copy()
df = df.T

df_main = calculate_government_changes(df)

df_main
# Out:
# country Australia Denmark Norway Belgium France New Zealand Sweden  \
# 1900          NaN     NaN  False   False    NaN         NaN    NaN
# 1901        False   False    NaN     NaN    NaN         NaN    NaN
# 1902          NaN     NaN    NaN   False  False       False    NaN
# 1903         True   False   True     NaN    NaN         NaN    NaN
# 1904          NaN     NaN    NaN   False    NaN         NaN    NaN
# ...           ...     ...    ...     ...    ...         ...    ...
# 2019        False   False    NaN   False    NaN         NaN    NaN
# 2020          NaN     NaN    NaN     NaN    NaN        True    NaN
# 2021          NaN     NaN  False     NaN    NaN         NaN    NaN
# 2022        False   False    NaN     NaN  False         NaN  False
# 2023          NaN     NaN    NaN     NaN    NaN         NaN    NaN
#
# country Switzerland Canada Finland  ... Latvia Romania Slovakia Slovenia  \
# 1900            NaN  False     NaN  ...    NaN     NaN      NaN      NaN
# 1901            NaN    NaN     NaN  ...    NaN     NaN      NaN      NaN
# 1902          False    NaN     NaN  ...    NaN     NaN      NaN      NaN
# 1903            NaN    NaN     NaN  ...    NaN     NaN      NaN      NaN
# 1904            NaN  False     NaN  ...    NaN     NaN      NaN      NaN
# ...             ...    ...     ...  ...    ...     ...      ...      ...
# 2019          False   True    True  ...    NaN     NaN      NaN      NaN
# 2020            NaN    NaN     NaN  ...    NaN   False     True      NaN
# 2021            NaN  False     NaN  ...    NaN     NaN      NaN      NaN
# 2022            NaN    NaN     NaN  ...   True     NaN      NaN     True
# 2023            NaN    NaN    True  ...    NaN     NaN      NaN      NaN
#
# country Poland Cyprus Lithuania Bulgaria Croatia Estonia
# 1900       NaN    NaN       NaN      NaN     NaN     NaN
# 1901       NaN    NaN       NaN      NaN     NaN     NaN
# 1902       NaN    NaN       NaN      NaN     NaN     NaN
# 1903       NaN    NaN       NaN      NaN     NaN     NaN
# 1904       NaN    NaN       NaN      NaN     NaN     NaN
# ...        ...    ...       ...      ...     ...     ...
# 2019     False    NaN       NaN      NaN     NaN   False
# 2020       NaN    NaN     False      NaN   False     NaN
# 2021       NaN  False       NaN     True     NaN     NaN
# 2022       NaN    NaN       NaN     True     NaN     NaN
# 2023       NaN    NaN       NaN    False     NaN   False
#
# [121 rows x 37 columns]

# %% [markdown]
# ## Adding USA Presidential Elections

# %%
# Function to get the winner's party for a given year
def get_winner_party(year):
    url = f"https://www.270towin.com/{year}-election"
    response = requests.get(url)
    
    # Check if the page is found
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the table with election results
        table = soup.find('table', {'class': 'table'})
        
        if table:
            # Extract all rows from the table
            rows = table.find_all('tr')
            
            # Look for the row with the winner (marked by ✓)
            for row in rows:
                cols = row.find_all('td')
                
                if len(cols) > 3 and '✓' in cols[0].text:
                    winner_name = cols[2].text.strip()
                    winner_party = cols[3].text.strip()
                    return winner_party
    return np.nan  # Return None if page or data is not found

# Create an empty list to store the data
data = []

# Loop through the years from 1900 to 2023
for year in range(1900, 2024):
    winner_party = get_winner_party(year)
    data.append([year, winner_party])

# Create a DataFrame
df = pd.DataFrame(data, columns=["Year", "Winner_Party"])

# Display the DataFrame sorted by year
df = df.sort_values(by="Year").reset_index(drop=True)
df = df.set_index("Year")


##Apply the bool func to df_usa
df_usa = df.copy()
df_usa = calculate_government_changes(df_usa)

# %%
df_usa = df_usa.rename(columns={"Winner_Party": "USA"})
df_main = pd.concat([df_main, df_usa], axis = 1)

# %% [markdown]
# ## Adding Other Countries via Manual Imputation

# %%
df_main["Costa_Rica"], df_main["Columbia"], df_main["Czechia"],df_main["Chile"],df_main["Lithuania"], df_main["Latvia"], df_main["Mexico"] = np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan

#Lithuania
df_main.loc[[1992,1996,2000,2004,2008,2012,2016,2020], 'Lithuania'] = True

#Czechia
df_main.loc[[1990,1992,1998,2006,2010,2017,2021], 'Czechia'] = True
df_main.loc[[1996,2002,2013], 'Czechia'] = False

#Chile
df_main.loc[[1999,2005,2009,2013,2017,2021], 'Chile'] = True
df_main.loc[[1989,1993], 'Chile'] = False


#Columbia
df_main.loc[[1998,2002,2010,2018,2022], 'Columbia'] = True
df_main.loc[[1990,1994,2006,2014], 'Columbia'] = False

#Latvia
df_main.loc[[1993,1999,2007,2011,2019,2023], 'Latvia'] = True
df_main.loc[[1996,2003,2015], 'Latvia'] = False

#Mexico
df_main.loc[[1988, 1994, 2000, 2006, 2012, 2018], 'Mexico'] = True

# %%
df_main.to_csv("ElectionChangesFinal.csv")

# %%
df_main.head(20)
# Out:
#      Australia Denmark Norway Belgium France New Zealand Sweden Switzerland  \
# 1900       NaN     NaN  False   False    NaN         NaN    NaN         NaN
# 1901     False   False    NaN     NaN    NaN         NaN    NaN         NaN
# 1902       NaN     NaN    NaN   False  False       False    NaN       False
# 1903      True   False   True     NaN    NaN         NaN    NaN         NaN
# 1904       NaN     NaN    NaN   False    NaN         NaN    NaN         NaN
# 1905       NaN     NaN    NaN     NaN    NaN       False    NaN       False
# 1906     False   False   True   False   True         NaN    NaN         NaN
# 1908       NaN     NaN    NaN   False    NaN       False    NaN       False
# 1909       NaN    True   True     NaN    NaN         NaN    NaN         NaN
# 1910      True    True    NaN   False   True         NaN    NaN         NaN
# 1911       NaN     NaN    NaN     NaN    NaN       False  False       False
# 1912       NaN     NaN   True   False    NaN         NaN    NaN         NaN
# 1913      True    True    NaN     NaN    NaN         NaN    NaN         NaN
# 1914      True     NaN    NaN   False   True        True   True       False
# 1915       NaN     NaN  False     NaN    NaN         NaN    NaN         NaN
# 1917      True     NaN    NaN     NaN    NaN         NaN   True       False
# 1918       NaN    True   True     NaN    NaN         NaN    NaN         NaN
# 1919     False     NaN    NaN    True   True       False    NaN       False
# 1920       NaN   False    NaN     NaN    NaN         NaN  False         NaN
# 1921       NaN     NaN   True    True    NaN         NaN  False         NaN
#
#      Canada Finland  ... Lithuania Bulgaria Croatia Estonia    USA Costa_Rica  \
# 1900  False     NaN  ...       NaN      NaN     NaN     NaN  False        NaN
# 1901    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1902    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1903    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1904  False     NaN  ...       NaN      NaN     NaN     NaN  False        NaN
# 1905    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1906    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1908  False     NaN  ...       NaN      NaN     NaN     NaN  False        NaN
# 1909    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1910    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1911   True     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1912    NaN     NaN  ...       NaN      NaN     NaN     NaN   True        NaN
# 1913    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1914    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1915    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1917  False   False  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1918    NaN     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1919    NaN   False  ...       NaN      NaN     NaN     NaN    NaN        NaN
# 1920    NaN     NaN  ...       NaN      NaN     NaN     NaN   True        NaN
# 1921   True     NaN  ...       NaN      NaN     NaN     NaN    NaN        NaN
#
#      Columbia Czechia Chile Mexico
# 1900      NaN     NaN   NaN    NaN
# 1901      NaN     NaN   NaN    NaN
# 1902      NaN     NaN   NaN    NaN
# 1903      NaN     NaN   NaN    NaN
# 1904      NaN     NaN   NaN    NaN
# 1905      NaN     NaN   NaN    NaN
# 1906      NaN     NaN   NaN    NaN
# 1908      NaN     NaN   NaN    NaN
# 1909      NaN     NaN   NaN    NaN
# 1910      NaN     NaN   NaN    NaN
# 1911      NaN     NaN   NaN    NaN
# 1912      NaN     NaN   NaN    NaN
# 1913      NaN     NaN   NaN    NaN
# 1914      NaN     NaN   NaN    NaN
# 1915      NaN     NaN   NaN    NaN
# 1917      NaN     NaN   NaN    NaN
# 1918      NaN     NaN   NaN    NaN
# 1919      NaN     NaN   NaN    NaN
# 1920      NaN     NaN   NaN    NaN
# 1921      NaN     NaN   NaN    NaN
#
# [20 rows x 43 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=63ad4e1b-19bb-4dd7-a997-1fa3d2fd82a1' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
